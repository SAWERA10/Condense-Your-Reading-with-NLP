# %% [markdown]
# # 0. Installing Transformers and Importing Dependencies

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %% [markdown]
# # 1. Load Summarization Pipeline

# %%
summarizer = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# ...

# %% [markdown]
# # 2. Summarize Text

# %%
ARTICLE = """ Multi-Stage Summarization Approach: The paper introduces a multi-stage long document summarization method that divides a long document into segments, generates coarse summaries in multiple stages, and produces the final summary using the last coarse summary. This approach offers flexibility in processing documents of varying lengths.

Enhanced Coarse Summarizer: The proposed method focuses on enhancing the coarse summarizer by generating new aligned pairs that include only relevant document segments. By incorporating contrastive learning into the training process, the method aims to maximize the similarities between source segments and target summaries.

Target-Focused Aligned Pairs: The paper introduces a new alignment function that aligns each target segment with a document segment to maximize ROUGE scores. This ensures that only relevant document segments are included in the training data, improving the quality of the generated summaries.

Experimental Validation: Extensive experiments on six long document summarization datasets demonstrate the effectiveness of the proposed method. The enhanced coarse summarizer outperforms existing approaches and achieves performance comparable to state-of-the-art models, showcasing its competitiveness in capturing salient information.

Comparison with Baselines: The proposed method is compared with SUMM-N and other models, showing superior performance in terms of ROUGE scores. The results highlight the significance of the enhanced coarse summarizer in improving the multi-stage summarization approach.

Effectiveness of Target-Focused Alignment: An ablation study reveals that training the coarse summarizer using target-focused alignment and contrastive learning significantly improves performance compared to using only target summaries or source segments. This emphasizes the importance of aligning relevant segments for effective summarization.

Quality of Coarse Summaries: Analysis of coarse summaries at different stages shows that the proposed method generates summaries enriched with key phrases and relevant content. A comparison with existing methods demonstrates the capacity of the proposed summarizer to produce concise and informative summaries.

Future Directions: The paper suggests future research directions in multi-stage summarization, encouraging further exploration of contrastive learning, target-focused alignment, and their application to diverse datasets and languages. This sets the stage for advancements in long document summarization techniques.

Acknowledgments: The paper acknowledges support from funding agencies, highlighting the collaborative efforts and resources that contributed to the development and validation of the proposed method. This underscores the importance of external support in advancing research in the field.
"""

# %%
summarizer(ARTICLE, max_length=400, min_length=200, do_sample=False)
# Out:
# [{'summary_text': ' The paper introduces a multi-stage long document summarization method that divides a long document into segments, generates coarse summaries in multiple stages, and produces the final summary using the last coarse summary . The proposed method focuses on enhancing the coarse summarizer by generating new aligned pairs that include only relevant document segments . By incorporating contrastive learning into the training process, the method aims to maximize the similarities between source segments and target summaries . The enhanced coarse summaryizer outperforms existing approaches and achieves performance comparable to state-of-the-art models, showcasing its competitiveness in capturing salient information . The paper acknowledges support from funding agencies, highlighting the collaborative efforts and resources that contributed to the development and validation of the proposed method . This underscores the importance of external support in advancing research in t
# ...
